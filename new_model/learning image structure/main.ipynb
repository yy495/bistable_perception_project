# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import scipy.io as sio
test1 = sio.loadmat('2022.mat')
im1 = test1['X']

test2 = sio.loadmat('bridge.mat')
im2 = test2['X']

test3 = sio.loadmat('flamingo.mat')
im3 = test3['X']

test4 = sio.loadmat('lighthouse.mat')
im4 = test4['X']

test5 = sio.loadmat('SF2_competition_image_2018.mat')
im5 = test5['X']

test6 = sio.loadmat('SF2_competition_image_2019.mat')
im6 = test6['X']
# Out:
# /Users/guoj/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
im1p = np.abs(np.fft.ifft2(np.fft.fft2(im1)/np.abs(np.fft.fft2(im1))))

# %%
plt.rcParams["figure.figsize"] = (10,10)
fig, axs = plt.subplots(8, 8)
for i in range(8):
    for j in range(8):
        a = np.random.randint(1,244)
        b = np.random.randint(1,244)
        axs[i, j].imshow(im4[a:a+12,b:b+12])
        axs[i,j].set_xticks([])
        axs[i,j].set_yticks([])
